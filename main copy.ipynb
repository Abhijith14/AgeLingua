# %% [markdown]
# # Analysing dialogues between speakers of different ages

# %% [markdown]
# ## Task 1: Description of Data and Methods (10/50) – (~max 600 words)

# %%
import os
import random
from collections import defaultdict
from pprint import pprint

import numpy as np
import pandas as pd

from lxml import etree

import altair as alt

# %% [markdown]
# The aim is to create a dataframe that deals with:
# - Speaker
# - age-range
# - utterances
# - individual tokens in that utterances
# - word classes for those tokens (check if that provides any insights during classification)
# - other utterance, dialogue, word variables

# %% [markdown]
# Variables like speaker, agerange, utterances and other related statistics can be collected from untagged. But inorder to get the tokens and their respective classes, tagged files should also be included.
# - dir_corpus : untagged
# - dir_corpus2 : tagged

# %%
dir_corpus = 'bnc2014spoken-xml/spoken/untagged/'
print(dir_corpus)
f_names = os.listdir(dir_corpus)
f_paths = [f"{dir_corpus}{f_name}" for f_name in f_names]
# Out:
# bnc2014spoken-xml/spoken/untagged/

# %%
dir_corpus2 = 'bnc2014spoken-xml/spoken/tagged/'
print(dir_corpus2)
f_names2 = os.listdir(dir_corpus2)
f_paths2 = [f"{dir_corpus2}{f_name}" for f_name in f_names2]

f_paths2 = ['bnc2014spoken-xml/spoken/tagged/S2A5-tgd.xml']

print(f_paths2)
# Out:
# bnc2014spoken-xml/spoken/tagged/
# ['bnc2014spoken-xml/spoken/tagged/S2A5-tgd.xml']

# %%
# delete cell

f_paths = ['bnc2014spoken-xml/spoken/untagged/S2A5.xml']

f_paths
# Out:
# ['bnc2014spoken-xml/spoken/untagged/S2A5.xml']

# %% [markdown]
# Now that we have the xml files ready, lets start organizing the data into a dataframe. Start with the untagged files. It can be split into 2 parts. The speakers are extracted to df_speakers and the utterances are extracted to df_utts. A list is created to append all the data to a single variable and then is later converted to 2 dataframes each for total speakers and total utterances.

# %%
dialogue_data = []
for path in f_paths: # for each of the dialogues
    print(path)
    df_utts = pd.read_xml(path, xpath="//u")
    # add the diaogue file name to the dataframe
    df_utts['dialogue'] = path.split('/')[-1].replace(".xml", "")
    df_speakers = pd.read_xml(path, xpath="//speaker")
    dialogue_data.append((df_utts, df_speakers))
# Out:
# bnc2014spoken-xml/spoken/untagged/S2A5.xml

# %% [markdown]
# The tagged data follows the same process, except we include the words and their classes in the utterances. All the words and their related variables are extracted to df_word_data.

# %% [markdown]
# - df_all_speakers : contains all the speakers and their related variables.
# - df_all_utts : contains all the utterances and their related variables.
# - df_word_data : contains all the words and their related variables.

# %%
def get_xml(f_path):
    with open(f_path, 'r') as f:
        f = f.read()
    xml = etree.fromstring(f)
    return xml

# %%
dialogue_data2 = []
for path in f_paths2:  # for each of the dialogues
    for i in get_xml(path).xpath('//u'):
        u_n = i.xpath('./@n')[0]
        u_who = i.xpath('./@who')[0]
        u_trans = i.xpath('./@trans')[0]
        u_confidence = i.xpath('./@whoConfidence')[0]

        full_data = []
        w_pos_data = []
        w_lemma_data = []
        w_class_data = []
        w_usas_data = []
        w_words_data = []
        for w in i.xpath('.//w'):
            w_pos_data.append(w.xpath('./@pos')[0])
            w_lemma_data.append(w.xpath('./@lemma')[0])
            w_class_data.append(w.xpath('./@class')[0])
            w_usas_data.append(w.xpath('./@usas')[0])
            w_words_data.append(w.xpath('./text()')[0])
        
        full_data.append({
                'u_n': u_n,
                'u_who': u_who,
                'u_trans': u_trans,
                'u_confidence': u_confidence,
                'w_pos': w_pos_data,
                'w_lemma': w_lemma_data,
                'w_class': w_class_data,
                'w_usas': w_usas_data,
                'w_words': w_words_data,
                'dialogue': path.split('/')[-1].replace("-tgd.xml", "")
        })

        dialogue_data2.extend(full_data)

df_word_data = pd.DataFrame(dialogue_data2)

# %%
df_word_data
# Out:
#      u_n  u_who     u_trans u_confidence
# 0      1  S0024  nonoverlap         high  \
# 1      2  S0144  nonoverlap         high
# 2      3  S0024  nonoverlap         high
# 3      4  S0144  nonoverlap         high
# 4      5  S0024  nonoverlap         high
# ..   ...    ...         ...          ...
# 228  229  S0024  nonoverlap         high
# 229  230  S0144  nonoverlap         high
# 230  231  S0024  nonoverlap         high
# 231  232  S0144  nonoverlap         high
# 232  233  S0024     overlap         high
#
#                                                  w_pos
# 0        [AT1, NNT1, RRR, VV0, PPHS1, VVZ, RP, RG, JJ]  \
# 1                 [RR, PPHS1, VHD, DD2, MC, NNT2, RRR]
# 2    [UH, PPIS1, VV0, CCB, DD1, VBZ, RRQ, PPIS2, VB...
# 3                                                   []
# 4                                 [VDD, PPY, NN1, NP1]
# ..                                                 ...
# 228                                               [UH]
# 229                         [DDQ, VDZ, DD1, VVI, YQUE]
# 230                        [VVZ, AT, NN2, VBR, JJ, UH]
# 231  [UH, UH, UH, UH, PPIS1, VVD, JJ, IF, NN1, RR21...
# 232           [RR, PPHS1, VBZ, RR, DD, FU, VV0, PPHO1]
#
#                                                w_lemma
# 0    [a, hour, later, hope, she, stay, down, rather...  \
# 1         [well, she, have, those, two, hour, earlier]
# 2    [yeah, i, know, but, that, be, why, we, be, a,...
# 3                                                   []
# 4                         [do, you, text, --anonnamem]
# ..                                                 ...
# 228                                             [yeah]
# 229                       [what, do, that, mean, PUNC]
# 230                [mean, the, potato, be, ready, yay]
# 231  [oh, yeah, ooh, ooh, i, get, ready, for, bed, ...
# 232  [well, she, be, hardly, any, --unclearword, ta...
#
#                                                w_class
# 0    [ART, SUBST, ADV, VERB, PRON, VERB, ADV, ADV, ...  \
# 1              [ADV, PRON, VERB, ADJ, ADJ, SUBST, ADV]
# 2    [INTERJ, PRON, VERB, CONJ, ADJ, VERB, ADV, PRO...
# 3                                                   []
# 4                           [VERB, PRON, SUBST, SUBST]
# ..                                                 ...
# 228                                           [INTERJ]
# 229                      [PRON, VERB, ADJ, VERB, STOP]
# 230              [VERB, ART, SUBST, VERB, ADJ, INTERJ]
# 231  [INTERJ, INTERJ, INTERJ, INTERJ, PRON, VERB, A...
# 232       [ADV, PRON, VERB, ADV, ADJ, UNC, VERB, PRON]
#
#                                                 w_usas
# 0          [Z5, T1:3, T4, X2:6, Z8, M8, Z5, A13:5, T4]  \
# 1                     [A5:1, Z8, A9, Z5, N1, T1:3, N4]
# 2    [Z4, Z8, X2:2, Z5, Z8, A3, A2:2, Z8, A3, Z5, T...
# 3                                                   []
# 4                               [A1:1:1, Z8, Q1:2, Z1]
# ..                                                 ...
# 228                                               [Z4]
# 229                               [Z8, Z5, Z8, Q1:1, ]
# 230                       [Q1:1, Z5, L3, A3, O4:1, Z2]
# 231  [Z4, Z4, Z4, Z4, Z8, A2:1, O4:1, Z5, H5, N5, N...
# 232                [A5:1, Z8, A3, N5, N5, Z99, A9, Z8]
#
#                                                w_words dialogue
# 0    [an, hour, later, hope, she, stays, down, rath...     S2A5
# 1         [well, she, had, those, two, hours, earlier]     S2A5
# 2    [yeah, I, know, but, that, 's, why, we, 're, a...     S2A5
# 3                                                   []     S2A5
# 4                        [did, you, text, --ANONnameM]     S2A5
# ..                                                 ...      ...
# 228                                             [yeah]     S2A5
# 229                        [what, does, that, mean, ?]     S2A5
# 230            [means, the, potatoes, are, ready, yay]     S2A5
# 231  [oh, yeah, ooh, ooh, I, got, ready, for, bed, ...     S2A5
# 232  [well, she, 's, hardly, any, --UNCLEARWORD, ta...     S2A5
#
# [233 rows x 10 columns]

# %%
# Concatenate all speakers dataframes into one
df_all_speakers = pd.concat([speaker_data[1] for speaker_data in dialogue_data])
df_all_speakers
# Out:
#       id  exactage age1994 agerange gender      nat birthplace birthcountry
# 0  S0024        36   35_44    30_39      F  British    Norwich      England  \
# 1  S0144        36   35_44    30_39      M  British     London      England
#
#         l1 lingorig  ... dialect_l2 dialect_l3   dialect_l4      edqual
# 0  English  England  ...    england      south  unspecified  5_postgrad  \
# 1  English  England  ...    england      south  unspecified  5_postgrad
#
#   occupation socgrade nssec  l2 fls in_core
# 0   lecturer        A   1_2 NaN NaN       n
# 1   Lecturer        A   1_2 NaN NaN       y
#
# [2 rows x 25 columns]

# %%
# Concatenate all utterances dataframes into one
df_all_utts = pd.concat([utt_data[0] for utt_data in dialogue_data])
df_all_utts
# Out:
#        n    who                                                  u  pause
# 0      1  S0024                                      an hour later    NaN  \
# 1      2  S0144               well she had those two hours earlier    NaN
# 2      3  S0024  yeah I know but that's why we're an hour late ...    NaN
# 3      4  S0144                                               None    NaN
# 4      5  S0024                                       did you text    NaN
# ..   ...    ...                                                ...    ...
# 228  229  S0024                                               yeah    NaN
# 229  230  S0144                               what does that mean?    NaN
# 230  231  S0024                       means the potatoes are ready    NaN
# 231  232  S0144                                               None    NaN
# 232  233  S0024                                               well    NaN
#
#      vocal  anon   unclear    trans trunc  event dialogue
# 0      NaN   NaN      None     None  None    NaN     S2A5
# 1      NaN   NaN      None     None  None    NaN     S2A5
# 2      NaN   NaN      None     None  None    NaN     S2A5
# 3      NaN   NaN      None     None  None    NaN     S2A5
# 4      NaN   NaN      None     None  None    NaN     S2A5
# ..     ...   ...       ...      ...   ...    ...      ...
# 228    NaN   NaN      None     None  None    NaN     S2A5
# 229    NaN   NaN      None     None  None    NaN     S2A5
# 230    NaN   NaN      None     None  None    NaN     S2A5
# 231    NaN   NaN      None     None  None    NaN     S2A5
# 232    NaN   NaN  take her  overlap  None    NaN     S2A5
#
# [233 rows x 11 columns]

# %% [markdown]
# Next step would be to merge these 3 dataframes to a final dataframe that contains the required data for classification and analysis.
#
# - df_all_utts
#     - u_len : a variable that can be used to calculate the length of each utterances for a particular speaker.
#     - avg_u_len_per_speaker : a variable that can be used to calculate the average length of utterances for a particular speaker.
#
# - df_word_data

# %%
# create a new column called 'u_len' and get the count of total utterances for each speaker
df_all_utts['u_len'] = df_all_utts['u'].str.len()
# create a new column called 'avg_u_len_per_speaker' and get the average
df_all_utts['avg_u_len_per_speaker'] = df_all_utts.groupby('who')['u_len'].transform('mean')

# %%
# create a python script to drop pause, vocal, anon, unclear, trans, trunc, event from df_all_utts
df_all_utts = df_all_utts.drop(columns=['pause', 'vocal', 'anon', 'unclear', 'trans', 'trunc', 'event'])

# %%
df_word_data
# Out:
#      u_n  u_who     u_trans u_confidence
# 0      1  S0024  nonoverlap         high  \
# 1      2  S0144  nonoverlap         high
# 2      3  S0024  nonoverlap         high
# 3      4  S0144  nonoverlap         high
# 4      5  S0024  nonoverlap         high
# ..   ...    ...         ...          ...
# 228  229  S0024  nonoverlap         high
# 229  230  S0144  nonoverlap         high
# 230  231  S0024  nonoverlap         high
# 231  232  S0144  nonoverlap         high
# 232  233  S0024     overlap         high
#
#                                                  w_pos
# 0        [AT1, NNT1, RRR, VV0, PPHS1, VVZ, RP, RG, JJ]  \
# 1                 [RR, PPHS1, VHD, DD2, MC, NNT2, RRR]
# 2    [UH, PPIS1, VV0, CCB, DD1, VBZ, RRQ, PPIS2, VB...
# 3                                                   []
# 4                                 [VDD, PPY, NN1, NP1]
# ..                                                 ...
# 228                                               [UH]
# 229                         [DDQ, VDZ, DD1, VVI, YQUE]
# 230                        [VVZ, AT, NN2, VBR, JJ, UH]
# 231  [UH, UH, UH, UH, PPIS1, VVD, JJ, IF, NN1, RR21...
# 232           [RR, PPHS1, VBZ, RR, DD, FU, VV0, PPHO1]
#
#                                                w_lemma
# 0    [a, hour, later, hope, she, stay, down, rather...  \
# 1         [well, she, have, those, two, hour, earlier]
# 2    [yeah, i, know, but, that, be, why, we, be, a,...
# 3                                                   []
# 4                         [do, you, text, --anonnamem]
# ..                                                 ...
# 228                                             [yeah]
# 229                       [what, do, that, mean, PUNC]
# 230                [mean, the, potato, be, ready, yay]
# 231  [oh, yeah, ooh, ooh, i, get, ready, for, bed, ...
# 232  [well, she, be, hardly, any, --unclearword, ta...
#
#                                                w_class
# 0    [ART, SUBST, ADV, VERB, PRON, VERB, ADV, ADV, ...  \
# 1              [ADV, PRON, VERB, ADJ, ADJ, SUBST, ADV]
# 2    [INTERJ, PRON, VERB, CONJ, ADJ, VERB, ADV, PRO...
# 3                                                   []
# 4                           [VERB, PRON, SUBST, SUBST]
# ..                                                 ...
# 228                                           [INTERJ]
# 229                      [PRON, VERB, ADJ, VERB, STOP]
# 230              [VERB, ART, SUBST, VERB, ADJ, INTERJ]
# 231  [INTERJ, INTERJ, INTERJ, INTERJ, PRON, VERB, A...
# 232       [ADV, PRON, VERB, ADV, ADJ, UNC, VERB, PRON]
#
#                                                 w_usas
# 0          [Z5, T1:3, T4, X2:6, Z8, M8, Z5, A13:5, T4]  \
# 1                     [A5:1, Z8, A9, Z5, N1, T1:3, N4]
# 2    [Z4, Z8, X2:2, Z5, Z8, A3, A2:2, Z8, A3, Z5, T...
# 3                                                   []
# 4                               [A1:1:1, Z8, Q1:2, Z1]
# ..                                                 ...
# 228                                               [Z4]
# 229                               [Z8, Z5, Z8, Q1:1, ]
# 230                       [Q1:1, Z5, L3, A3, O4:1, Z2]
# 231  [Z4, Z4, Z4, Z4, Z8, A2:1, O4:1, Z5, H5, N5, N...
# 232                [A5:1, Z8, A3, N5, N5, Z99, A9, Z8]
#
#                                                w_words dialogue
# 0    [an, hour, later, hope, she, stays, down, rath...     S2A5
# 1         [well, she, had, those, two, hours, earlier]     S2A5
# 2    [yeah, I, know, but, that, 's, why, we, 're, a...     S2A5
# 3                                                   []     S2A5
# 4                        [did, you, text, --ANONnameM]     S2A5
# ..                                                 ...      ...
# 228                                             [yeah]     S2A5
# 229                        [what, does, that, mean, ?]     S2A5
# 230            [means, the, potatoes, are, ready, yay]     S2A5
# 231  [oh, yeah, ooh, ooh, I, got, ready, for, bed, ...     S2A5
# 232  [well, she, 's, hardly, any, --UNCLEARWORD, ta...     S2A5
#
# [233 rows x 10 columns]

# %%
df_all_utts[df_all_utts['who'] == 'S0024']['u'].unique()
# Out:
# array(['an hour later',
#        "yeah I know but that's why we're an hour late isn't it?",
#        'did you text', 'oh', 'some people get jet lag', 'mm',
#        'everybody says this direction', 'yeah', 'we were both', 'we no',
#        None, 'I hope she sleep tonight', "I'm fed up of her getting up",
#        'no', 'she slept in my in our bed',
#        "again and I've got and I'm not allowed to do that cos I wake her up hi and I'm like oh",
#        'and they say you', "but she just wouldn't settle down",
#        'and she settled down when she was being cuddled',
#        'a bit worried that her',
#        'her change happened from cuddling I think',
#        "right at the end of the holiday which means that she's jet-lagged and she's gets",
#        'and so', "can't like can't be mean",
#        "gotta be confused as a baby haven't you?", 'all of that',
#        'wanna go through the new bag actually', "and there's two pairs",
#        'so', "so we'll see how she goes",
#        "I mean she's fine in all her dresses at the moment",
#        "they're getting a bit short though",
#        'getting shorter and shorter and shorter like little tops',
#        'with a nappy poking underneath',
#        'no I do like when going out I do like to put on you know nice little like that',
#        "no it's because she", "well I've got rubbish clothes",
#        'cos she smiles so much', 'chooses one', 'and grabs one',
#        "oh you're so cute", "you've gotta have", 'blue',
#        "yeah if she was in grey do you think she'd feel good? I don't think she would",
#        "I think she'd feel rubbish if", 'no I want',
#        'I want her to feel lovely', 'did you just say uh?',
#        'sleep for three years?',
#        "what till she's three years old? four years old? don't think you're gonna get any sleep",
#        "but we've got to learn to survive without sleep now",
#        "that'd be great", 'ah I', 'camomile',
#        "ah that'll do we'll send that",
#        "yeah or maybe it's something like that yeah", 'I thought',
#        'er yeah tonic water', 'whisky you can just have with hot water',
#        'it what is that a hot toddy or something?', 'hot toddy?',
#        'or have a whisky hot chocolate',
#        "been such a long time since I've",
#        'yeah you know my bullet blender?', 'that I keep talking about',
#        "can't I get it for Christmas?", 'I found it on Taobao',
#        "but er and it's like twenty quid",
#        'well it says a hundred and eighty-nine',
#        'and you add on the accessories and then it ends up',
#        "loads more money? well I think it's probably something like that I need to",
#        'they give you different coloured rims', 'for the glasses',
#        'they each one you just plug it into the',
#        "you've got a coloured rim with a coloured handle so you'd know whose is whose",
#        "it doesn't plug into the blender?", 'oh more than that',
#        "cos it's got other bits too", 'right',
#        'the cup fits on to the blender', 'and you make your cocktail',
#        'then you take your cup off and you drink it',
#        "you can't do that with a normal cup can you?",
#        "so that you know which cocktail you've made",
#        "so that if if you're",
#        "you don't want to pick up mine and make your cocktail in it",
#        "well if we ever have they're calling them bullet parties",
#        'bullet cocktail party', 'bullet party', 'and you all make',
#        'a cocktail each', 'oh I watched it one time in',
#        "yeah that's what",
#        'cocktail is a cocktail party but you drink it out of a big mug instead of a fancy glass',
#        "she's asleep", 'means the potatoes are ready', 'well'],
#       dtype=object)

# %%
# merge df_all_utts and df_word_data on 'who' from df_all_utts and 'u_who' from df_word_data
df_all_utts = df_all_utts.merge(df_word_data, left_on='who', right_on='u_who')

df_all_utts
# Out:
#          n    who              u dialogue_x  u_len  avg_u_len_per_speaker
# 0        1  S0024  an hour later       S2A5   13.0              27.085714  \
# 1        1  S0024  an hour later       S2A5   13.0              27.085714
# 2        1  S0024  an hour later       S2A5   13.0              27.085714
# 3        1  S0024  an hour later       S2A5   13.0              27.085714
# 4        1  S0024  an hour later       S2A5   13.0              27.085714
# ...    ...    ...            ...        ...    ...                    ...
# 27140  232  S0144           None       S2A5    NaN              21.988889
# 27141  232  S0144           None       S2A5    NaN              21.988889
# 27142  232  S0144           None       S2A5    NaN              21.988889
# 27143  232  S0144           None       S2A5    NaN              21.988889
# 27144  232  S0144           None       S2A5    NaN              21.988889
#
#        u_n  u_who     u_trans u_confidence
# 0        1  S0024  nonoverlap         high  \
# 1        3  S0024  nonoverlap         high
# 2        5  S0024  nonoverlap         high
# 3        7  S0024  nonoverlap         high
# 4        9  S0024  nonoverlap         high
# ...    ...    ...         ...          ...
# 27140  224  S0144  nonoverlap         high
# 27141  226  S0144  nonoverlap         high
# 27142  228  S0144  nonoverlap         high
# 27143  230  S0144  nonoverlap         high
# 27144  232  S0144  nonoverlap         high
#
#                                                    w_pos
# 0          [AT1, NNT1, RRR, VV0, PPHS1, VVZ, RP, RG, JJ]  \
# 1      [UH, PPIS1, VV0, CCB, DD1, VBZ, RRQ, PPIS2, VB...
# 2                                   [VDD, PPY, NN1, NP1]
# 3                                                   [UH]
# 4             [DD, NN, VV0, NN1, NN1, RRR, CSN, NN2, UH]
# ...                                                  ...
# 27140                                               [UH]
# 27141                             [PPHS1, VBZ, JJ, YQUE]
# 27142  [RR, RR, PPIS1, VVD, AT, NN1, VVI, RR21, RR22,...
# 27143                         [DDQ, VDZ, DD1, VVI, YQUE]
# 27144  [UH, UH, UH, UH, PPIS1, VVD, JJ, IF, NN1, RR21...
#
#                                                  w_lemma
# 0      [a, hour, later, hope, she, stay, down, rather...  \
# 1      [yeah, i, know, but, that, be, why, we, be, a,...
# 2                           [do, you, text, --anonnamem]
# 3                                                   [oh]
# 4      [some, people, get, jet, lag, longer, than, ot...
# ...                                                  ...
# 27140                                               [mm]
# 27141                            [she, be, asleep, PUNC]
# 27142  [okay, well, i, hear, the, oven, ping, as, wel...
# 27143                       [what, do, that, mean, PUNC]
# 27144  [oh, yeah, ooh, ooh, i, get, ready, for, bed, ...
#
#                                                  w_class
# 0      [ART, SUBST, ADV, VERB, PRON, VERB, ADV, ADV, ...  \
# 1      [INTERJ, PRON, VERB, CONJ, ADJ, VERB, ADV, PRO...
# 2                             [VERB, PRON, SUBST, SUBST]
# 3                                               [INTERJ]
# 4      [ADJ, SUBST, VERB, SUBST, SUBST, ADV, CONJ, SU...
# ...                                                  ...
# 27140                                           [INTERJ]
# 27141                            [PRON, VERB, ADJ, STOP]
# 27142  [ADV, ADV, PRON, VERB, ART, SUBST, VERB, ADV, ...
# 27143                      [PRON, VERB, ADJ, VERB, STOP]
# 27144  [INTERJ, INTERJ, INTERJ, INTERJ, PRON, VERB, A...
#
#                                                   w_usas
# 0            [Z5, T1:3, T4, X2:6, Z8, M8, Z5, A13:5, T4]  \
# 1      [Z4, Z8, X2:2, Z5, Z8, A3, A2:2, Z8, A3, Z5, T...
# 2                                 [A1:1:1, Z8, Q1:2, Z1]
# 3                                                   [Z4]
# 4               [N5, S2, A9, M5, M5, T1:3, Z5, A6:1, Z4]
# ...                                                  ...
# 27140                                               [Z4]
# 27141                                     [Z8, A3, B1, ]
# 27142     [A5:1, A5:1, Z8, X3:2, Z5, O2, Y2, N5, N5, Z5]
# 27143                               [Z8, Z5, Z8, Q1:1, ]
# 27144  [Z4, Z4, Z4, Z4, Z8, A2:1, O4:1, Z5, H5, N5, N...
#
#                                                  w_words dialogue_y
# 0      [an, hour, later, hope, she, stays, down, rath...       S2A5
# 1      [yeah, I, know, but, that, 's, why, we, 're, a...       S2A5
# 2                          [did, you, text, --ANONnameM]       S2A5
# 3                                                   [oh]       S2A5
# 4      [some, people, get, jet, lag, longer, than, ot...       S2A5
# ...                                                  ...        ...
# 27140                                               [mm]       S2A5
# 27141                               [she, 's, asleep, ?]       S2A5
# 27142  [okay, well, I, heard, the, oven, ping, as, we...       S2A5
# 27143                        [what, does, that, mean, ?]       S2A5
# 27144  [oh, yeah, ooh, ooh, I, got, ready, for, bed, ...       S2A5
#
# [27145 rows x 16 columns]

# %%
# display exactage and agerange of each speaker
df1 = df_all_speakers[['id', 'exactage', 'agerange','gender']]
df1
# Out:
#       id  exactage agerange gender
# 0  S0024        36    30_39      F
# 1  S0144        36    30_39      M

# %%
df_all_utts
# Out:
#          n    who              u dialogue_x  u_len  avg_u_len_per_speaker
# 0        1  S0024  an hour later       S2A5   13.0              27.085714  \
# 1        1  S0024  an hour later       S2A5   13.0              27.085714
# 2        1  S0024  an hour later       S2A5   13.0              27.085714
# 3        1  S0024  an hour later       S2A5   13.0              27.085714
# 4        1  S0024  an hour later       S2A5   13.0              27.085714
# ...    ...    ...            ...        ...    ...                    ...
# 27140  232  S0144           None       S2A5    NaN              21.988889
# 27141  232  S0144           None       S2A5    NaN              21.988889
# 27142  232  S0144           None       S2A5    NaN              21.988889
# 27143  232  S0144           None       S2A5    NaN              21.988889
# 27144  232  S0144           None       S2A5    NaN              21.988889
#
#        u_n  u_who     u_trans u_confidence
# 0        1  S0024  nonoverlap         high  \
# 1        3  S0024  nonoverlap         high
# 2        5  S0024  nonoverlap         high
# 3        7  S0024  nonoverlap         high
# 4        9  S0024  nonoverlap         high
# ...    ...    ...         ...          ...
# 27140  224  S0144  nonoverlap         high
# 27141  226  S0144  nonoverlap         high
# 27142  228  S0144  nonoverlap         high
# 27143  230  S0144  nonoverlap         high
# 27144  232  S0144  nonoverlap         high
#
#                                                    w_pos
# 0          [AT1, NNT1, RRR, VV0, PPHS1, VVZ, RP, RG, JJ]  \
# 1      [UH, PPIS1, VV0, CCB, DD1, VBZ, RRQ, PPIS2, VB...
# 2                                   [VDD, PPY, NN1, NP1]
# 3                                                   [UH]
# 4             [DD, NN, VV0, NN1, NN1, RRR, CSN, NN2, UH]
# ...                                                  ...
# 27140                                               [UH]
# 27141                             [PPHS1, VBZ, JJ, YQUE]
# 27142  [RR, RR, PPIS1, VVD, AT, NN1, VVI, RR21, RR22,...
# 27143                         [DDQ, VDZ, DD1, VVI, YQUE]
# 27144  [UH, UH, UH, UH, PPIS1, VVD, JJ, IF, NN1, RR21...
#
#                                                  w_lemma
# 0      [a, hour, later, hope, she, stay, down, rather...  \
# 1      [yeah, i, know, but, that, be, why, we, be, a,...
# 2                           [do, you, text, --anonnamem]
# 3                                                   [oh]
# 4      [some, people, get, jet, lag, longer, than, ot...
# ...                                                  ...
# 27140                                               [mm]
# 27141                            [she, be, asleep, PUNC]
# 27142  [okay, well, i, hear, the, oven, ping, as, wel...
# 27143                       [what, do, that, mean, PUNC]
# 27144  [oh, yeah, ooh, ooh, i, get, ready, for, bed, ...
#
#                                                  w_class
# 0      [ART, SUBST, ADV, VERB, PRON, VERB, ADV, ADV, ...  \
# 1      [INTERJ, PRON, VERB, CONJ, ADJ, VERB, ADV, PRO...
# 2                             [VERB, PRON, SUBST, SUBST]
# 3                                               [INTERJ]
# 4      [ADJ, SUBST, VERB, SUBST, SUBST, ADV, CONJ, SU...
# ...                                                  ...
# 27140                                           [INTERJ]
# 27141                            [PRON, VERB, ADJ, STOP]
# 27142  [ADV, ADV, PRON, VERB, ART, SUBST, VERB, ADV, ...
# 27143                      [PRON, VERB, ADJ, VERB, STOP]
# 27144  [INTERJ, INTERJ, INTERJ, INTERJ, PRON, VERB, A...
#
#                                                   w_usas
# 0            [Z5, T1:3, T4, X2:6, Z8, M8, Z5, A13:5, T4]  \
# 1      [Z4, Z8, X2:2, Z5, Z8, A3, A2:2, Z8, A3, Z5, T...
# 2                                 [A1:1:1, Z8, Q1:2, Z1]
# 3                                                   [Z4]
# 4               [N5, S2, A9, M5, M5, T1:3, Z5, A6:1, Z4]
# ...                                                  ...
# 27140                                               [Z4]
# 27141                                     [Z8, A3, B1, ]
# 27142     [A5:1, A5:1, Z8, X3:2, Z5, O2, Y2, N5, N5, Z5]
# 27143                               [Z8, Z5, Z8, Q1:1, ]
# 27144  [Z4, Z4, Z4, Z4, Z8, A2:1, O4:1, Z5, H5, N5, N...
#
#                                                  w_words dialogue_y
# 0      [an, hour, later, hope, she, stays, down, rath...       S2A5
# 1      [yeah, I, know, but, that, 's, why, we, 're, a...       S2A5
# 2                          [did, you, text, --ANONnameM]       S2A5
# 3                                                   [oh]       S2A5
# 4      [some, people, get, jet, lag, longer, than, ot...       S2A5
# ...                                                  ...        ...
# 27140                                               [mm]       S2A5
# 27141                               [she, 's, asleep, ?]       S2A5
# 27142  [okay, well, I, heard, the, oven, ping, as, we...       S2A5
# 27143                        [what, does, that, mean, ?]       S2A5
# 27144  [oh, yeah, ooh, ooh, I, got, ready, for, bed, ...       S2A5
#
# [27145 rows x 16 columns]

# %%
df_word_data
# Out:
#      u_n  u_who     u_trans u_confidence
# 0      1  S0024  nonoverlap         high  \
# 1      2  S0144  nonoverlap         high
# 2      3  S0024  nonoverlap         high
# 3      4  S0144  nonoverlap         high
# 4      5  S0024  nonoverlap         high
# ..   ...    ...         ...          ...
# 228  229  S0024  nonoverlap         high
# 229  230  S0144  nonoverlap         high
# 230  231  S0024  nonoverlap         high
# 231  232  S0144  nonoverlap         high
# 232  233  S0024     overlap         high
#
#                                                  w_pos
# 0        [AT1, NNT1, RRR, VV0, PPHS1, VVZ, RP, RG, JJ]  \
# 1                 [RR, PPHS1, VHD, DD2, MC, NNT2, RRR]
# 2    [UH, PPIS1, VV0, CCB, DD1, VBZ, RRQ, PPIS2, VB...
# 3                                                   []
# 4                                 [VDD, PPY, NN1, NP1]
# ..                                                 ...
# 228                                               [UH]
# 229                         [DDQ, VDZ, DD1, VVI, YQUE]
# 230                        [VVZ, AT, NN2, VBR, JJ, UH]
# 231  [UH, UH, UH, UH, PPIS1, VVD, JJ, IF, NN1, RR21...
# 232           [RR, PPHS1, VBZ, RR, DD, FU, VV0, PPHO1]
#
#                                                w_lemma
# 0    [a, hour, later, hope, she, stay, down, rather...  \
# 1         [well, she, have, those, two, hour, earlier]
# 2    [yeah, i, know, but, that, be, why, we, be, a,...
# 3                                                   []
# 4                         [do, you, text, --anonnamem]
# ..                                                 ...
# 228                                             [yeah]
# 229                       [what, do, that, mean, PUNC]
# 230                [mean, the, potato, be, ready, yay]
# 231  [oh, yeah, ooh, ooh, i, get, ready, for, bed, ...
# 232  [well, she, be, hardly, any, --unclearword, ta...
#
#                                                w_class
# 0    [ART, SUBST, ADV, VERB, PRON, VERB, ADV, ADV, ...  \
# 1              [ADV, PRON, VERB, ADJ, ADJ, SUBST, ADV]
# 2    [INTERJ, PRON, VERB, CONJ, ADJ, VERB, ADV, PRO...
# 3                                                   []
# 4                           [VERB, PRON, SUBST, SUBST]
# ..                                                 ...
# 228                                           [INTERJ]
# 229                      [PRON, VERB, ADJ, VERB, STOP]
# 230              [VERB, ART, SUBST, VERB, ADJ, INTERJ]
# 231  [INTERJ, INTERJ, INTERJ, INTERJ, PRON, VERB, A...
# 232       [ADV, PRON, VERB, ADV, ADJ, UNC, VERB, PRON]
#
#                                                 w_usas
# 0          [Z5, T1:3, T4, X2:6, Z8, M8, Z5, A13:5, T4]  \
# 1                     [A5:1, Z8, A9, Z5, N1, T1:3, N4]
# 2    [Z4, Z8, X2:2, Z5, Z8, A3, A2:2, Z8, A3, Z5, T...
# 3                                                   []
# 4                               [A1:1:1, Z8, Q1:2, Z1]
# ..                                                 ...
# 228                                               [Z4]
# 229                               [Z8, Z5, Z8, Q1:1, ]
# 230                       [Q1:1, Z5, L3, A3, O4:1, Z2]
# 231  [Z4, Z4, Z4, Z4, Z8, A2:1, O4:1, Z5, H5, N5, N...
# 232                [A5:1, Z8, A3, N5, N5, Z99, A9, Z8]
#
#                                                w_words dialogue
# 0    [an, hour, later, hope, she, stays, down, rath...     S2A5
# 1         [well, she, had, those, two, hours, earlier]     S2A5
# 2    [yeah, I, know, but, that, 's, why, we, 're, a...     S2A5
# 3                                                   []     S2A5
# 4                        [did, you, text, --ANONnameM]     S2A5
# ..                                                 ...      ...
# 228                                             [yeah]     S2A5
# 229                        [what, does, that, mean, ?]     S2A5
# 230            [means, the, potatoes, are, ready, yay]     S2A5
# 231  [oh, yeah, ooh, ooh, I, got, ready, for, bed, ...     S2A5
# 232  [well, she, 's, hardly, any, --UNCLEARWORD, ta...     S2A5
#
# [233 rows x 10 columns]

# %%
# get u, avg_u_len_per_speaker, dialogue for each speaker
df_counts = df_all_utts.groupby('who').agg({'u': 'count', 'avg_u_len_per_speaker': 'first', 'dialogue_y': 'count'})
df_counts.columns = ['total_utterances', 'avg_u_len_per_speaker', 'dialogue_count']
df_counts = df_counts.reset_index()
print(df_counts)
# Out:
#      who  total_utterances  avg_u_len_per_speaker  dialogue_count
# 0  S0024             12285              27.085714           13689
# 1  S0144             10440              21.988889           13456

# %%
# merge df1 and df_utts on the column 'who' and 'id' respectively
df_final = pd.merge(df1, df_counts, left_on='id', right_on='who')

# drop the column 'who'
df_final = df_final.drop(columns=['who'])

# remove duplicate rows in id column
df_final = df_final.drop_duplicates(subset=['id'])
df_final

# %%
df_final.describe()

# %%
# get the exactage of each speaker '60s'
print(df_final[df_final['exactage'] == '60s'])

# convert that '60s' to 60
df_final.loc[df_final['exactage'] == '60s', 'exactage'] = 60

print(df_final[df_final['exactage'] == '60s'])

# %%
# remove rows with missing values
df_final = df_final.dropna()

df_final.shape

# %%
# convert the column 'exactage' to integer
df_final['exactage'] = df_final['exactage'].astype(int)

# %%
# convert the gender column to categorical
# df_final['gender'] = pd.Categorical(df_final['gender']).codes
# df_final

# %%
df_final.describe()

# %%
df_final['agerange'].value_counts().sort_index()

# %%
df_final = df_final.sort_values('agerange')
df_final

# %%
import plotly.graph_objects as go

# create a pie chart of agerange distribution
fig = go.Figure(data=[go.Pie(labels=df_final['agerange'].value_counts().index,
                             values=df_final['agerange'].value_counts().values)])

# update the layout of the chart
fig.update_layout(title='Distribution of agerange')

# show the chart
fig.show()

# %%
df_final.dtypes

# %%
df_all_speakers

# %%
df_final.head()

# %%
# show the number of speakers in each age group
df_final['agerange'].value_counts()

# %%
df_agerange = df_final.groupby('agerange').agg({'total_utterances': 'sum', 'avg_u_len_per_speaker': 'mean', 'dialogue_count': 'sum', 'id': 'count'}).reset_index()
df_agerange.rename(columns={'avg_u_len_per_speaker': 'avg_u_len_per_agerange'}, inplace=True)
df_agerange.rename(columns={'dialogue_count': 'num_of_dialogues'}, inplace=True)
df_agerange.rename(columns={'id': 'num_of_speakers'}, inplace=True)

# add a new column 'avg_utterances_per_speaker'
df_agerange['avg_u_per_speaker'] = df_agerange['total_utterances'] / df_agerange['num_of_speakers']

# %%
df_agerange

# %%
df_agerange.describe()

# %%
df_agerange.iloc[[2, 5, 6, 7, 8, 9], :]

# %%
# create a new dataframe that contains the same number of columns but only 2 rows. one with 19_29 and the other with 50_59, 60_69 to 90_99
df_agerange_2 = df_agerange.iloc[[2, 5, 6, 7, 8, 9], :]

# sum the values of the rows 5, 6, 7, 8, 9 and assign it to the row 3
df_agerange_2.iloc[1, 1:] = df_agerange.iloc[5:10, 1:].sum()

# drop the rows 5, 6, 7, 8, 9
df_agerange_2 = df_agerange_2.drop([6, 7, 8, 9])

# now add a new column 'agegroup' to the dataframe that contains two values 'younger' and 'older'
df_agerange_2['agegroup'] = ['19-29', '50+']

# drop the column 'agerange'
df_agerange_2 = df_agerange_2.drop(columns=['agerange'])

# bring the column 'agegroup' to the first position
cols = df_agerange_2.columns.tolist()
cols = cols[-1:] + cols[:-1]
df_agerange_2 = df_agerange_2[cols]

# reset the index of the dataframe
df_agerange_2 = df_agerange_2.reset_index(drop=True)

df_agerange_2

# %%
df_agerange_2.describe()
